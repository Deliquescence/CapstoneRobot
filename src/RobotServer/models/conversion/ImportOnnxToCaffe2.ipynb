# %%
import onnx
import caffe2.python.onnx.backend
import numpy as np
from PIL import Image

# %%
model = onnx.load("../supervised.onnx")

# %%
#img = np.random.randn(1, 3, 240, 320).astype(np.float32)
image = Image.open("../../../../../first_train_data/train/mirrorB_2564.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x81D9C88>

# %%
img = np.array(image)
img.shape
img = img.reshape(1,3,240,320).astype(np.float32)
out = caffe2.python.onnx.backend.run_model(model, [img])
out
# Out:
# Original python traceback for operator `50` in network `torch-jit-export_predict` in exception above (most recent call last):
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-f687fe77cd2e> in <module>
#       2 img.shape
#       3 img = img.reshape(1,3,240,320).astype(np.float32)
# ----> 4 out = caffe2.python.onnx.backend.run_model(model, [img])
#       5 out
#
# c:\program files\python36\lib\site-packages\onnx\backend\base.py in run_model(cls, model, inputs, device, **kwargs)
#      84         backend = cls.prepare(model, device, **kwargs)
#      85         assert backend is not None
# ---> 86         return backend.run(inputs)
#      87
#      88     @classmethod
#
# c:\program files\python36\lib\site-packages\caffe2\python\onnx\backend_rep.py in run(self, inputs, **kwargs)
#      55                 self.workspace.RunNet(self.init_net.name)
# ...
